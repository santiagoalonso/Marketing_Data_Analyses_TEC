# %%
#Arrays and containers
import numpy as np
import pandas as pd

#Plotting
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
import plotnine as p9
from plotnine import ggplot, aes, coord_flip, geom_point, geom_line, geom_col, geom_linerange, geom_errorbarh
from plotnine import geom_density, geom_histogram, geom_bar, scale_x_reverse, scale_y_reverse, facet_grid
import bokeh
from bokeh.sampledata.us_states import data as USA_coords
import holoviews as hv
from holoviews import opts
#for the next, conda install scikit-image
#pip install datashader
from holoviews.operation.datashader import datashade, bundle_graph
hv.extension('bokeh') #Backend: matplotlib, plotly, bokeh
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ccc01d12-0455-4365-89f3-abb48c7f7ba2" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9848dc93-363e-4d56-b73c-a0c2f00823f9":{"version":"3.4.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"b7760fd896ba47c8a9aa602433c7ef84","client_comm_id":"44a3fbbb1317402aa7a361ebaf7313a9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"9848dc93-363e-4d56-b73c-a0c2f00823f9","roots":{"p1002":"ccc01d12-0455-4365-89f3-abb48c7f7ba2"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
def annotate_axes(fig):
    for i, ax in enumerate(fig.axes):
        ax.text(0.5, 0.5, "ax%d" % (i+1), va="center", ha="center")
        ax.tick_params(labelbottom=False, labelleft=False)

# %%
data_path = r'C:\Users\L03552670\Documents\GitHub\Marketing_Data_Analyses_TEC\Python\Data'+ "\\"
data_path
# Out:
# 'C:\\Users\\L03552670\\Documents\\GitHub\\Marketing_Data_Analyses_TEC\\Python\\Data\\'

# %% [markdown]
# # Exploratory Data Analysis
# Based on https://r4ds.hadley.nz/eda

# %% [markdown]
# Hadley Wickham recommends these two general questions to begin with:
#
# 1) What type of variation occurs within my variables?
# 2)
# What type of covariation occurs between my variables?

# %% [markdown]
# ## Load, prepare, and clean data

# %%
#Let's load some data
#This is a restaurant/grill. 
#It's data science team collected costumer's data
dataSF = pd.read_csv(data_path + "SantaFeGrill_4e.csv")

#Identify columns and data types
print(dataSF.dtypes)

#Drop unnecesary columns
dataSF.drop(columns = ["Unnamed: 0"], inplace=True)
# Out:
# Unnamed: 0                                                    int64
# ID                                                          float64
# Regularly Dine at Casual Dining Restaurants                 float64
# Have Dined at Other Mexican Restaurants In last 6 Months    float64
# Gross Annual Income $15,000 or More                         float64
# Favorite Mexican Restaurant                                  object
# X1 -- Try New and Different Things                           object
# X2 -- Party Person                                           object
# X3 -- People Come to Me                                      object
# X4 -- Avoid Fried Foods                                     float64
# X5 -- Likes to Go Out Socially                               object
# X6 -- Friends Come to Me                                     object
# X7 -- Self-Confident                                         object
# X8 -- Eat Balanced, Nutritious Meals                         object
# X9 -- Buy New Products                                       object
# X10 -- Careful about What I Eat                              object
# X11 -- Try New Brands                                        object
# X12 -- Friendly Employees                                    object
# X13 -- Fun Place to Eat                                      object
# X14 -- Large Size Portions                                  float64
# X15 -- Fresh Food                                            object
# X16 -- Reasonable Prices                                    float64
# X17 -- Attractive Interior                                   object
# X18 -- Excellent Food Taste                                  object
# X19 -- Knowledgeable Employees                               object
# X20 -- Proper Food Temperature                               object
# X21 -- Speed of Service                                      object
# X22 -- Satisfaction                                          object
# X23 -- Likely to Return                                      object
# X24 -- Likely to Recommend                                   object
# X25 -- Frequency of Eating at  . . .  ??                     object
# X26 -- Price                                                 object
# X27 -- Food Quality                                          object
# X28 -- Atmosphere                                            object
# X29 -- Service                                               object
# x30 -- Distance Driven                                       object
# X31 -- Ad Recall                                             object
# X32 -- Gender                                                object
# X33 -- Number of Children at Home                            object
# X34 -- Age                                                   object
# X35 -- Income                                               float64
# X36 -- Innovator                                             object
# X37 -- Health Conscious                                     float64
# X38 -- Opinion Leader                                        object
# X39 -- Outgoing                                              object
# X40 -- Service                                               object
# X41 -- Food                                                  object
# X42 -- Value                                                float64
# X43 -- Atmosphere                                            object
# dtype: object

# %%
#Change column names for shorter versions (and Python doesn't like spaces between variables)
dataSF.columns = ["ID", "Regular_Dine_Res", "Dine_Other_Mex_Res", "Income_15k_more",
                 "Fav_Mex_Res", "Try_New_Things", "Party_Person", "People_Come_Me", "No_Fried",
                 "Likes_Go_Out", "Friends_Come_Me", "Self_Confident", "Eat_Balanced",
                 "Buy_New_Prods", "Care_What_Eat", "Try_New_Brands", "Friendly_Employess",
                 "Fun_Place", "Large_Portions", "Fresh_Food", "Good_Prices", "Nice_Interior",
                 "Excellent_Taste", "Knowledgeable_Employees", "Proper_Food_Temp", 
                 "Speed_Service", "Satisfaction", "Prob_Return", "Prob_Recommend",
                 "Freq_Eat_At", "Price", "Food_Quality", "Atmosphere", "Service",
                 "Distance_Driven", "Ad_Recall", "Gender", "N_Children", "Age",
                 "Income", "Innovator", "Health_Conscious", "Opinion_Leader",
                 "Outgoing", "Service_v2", "Food", "Value", "Atmosphere_V2"]

print(dataSF.dtypes)
# Out:
# ID                         float64
# Regular_Dine_Res           float64
# Dine_Other_Mex_Res         float64
# Income_15k_more            float64
# Fav_Mex_Res                 object
# Try_New_Things              object
# Party_Person                object
# People_Come_Me              object
# No_Fried                   float64
# Likes_Go_Out                object
# Friends_Come_Me             object
# Self_Confident              object
# Eat_Balanced                object
# Buy_New_Prods               object
# Care_What_Eat               object
# Try_New_Brands              object
# Friendly_Employess          object
# Fun_Place                   object
# Large_Portions             float64
# Fresh_Food                  object
# Good_Prices                float64
# Nice_Interior               object
# Excellent_Taste             object
# Knowledgeable_Employees     object
# Proper_Food_Temp            object
# Speed_Service               object
# Satisfaction                object
# Prob_Return                 object
# Prob_Recommend              object
# Freq_Eat_At                 object
# Price                       object
# Food_Quality                object
# Atmosphere                  object
# Service                     object
# Distance_Driven             object
# Ad_Recall                   object
# Gender                      object
# N_Children                  object
# Age                         object
# Income                     float64
# Innovator                   object
# Health_Conscious           float64
# Opinion_Leader              object
# Outgoing                    object
# Service_v2                  object
# Food                        object
# Value                      float64
# Atmosphere_V2               object
# dtype: object

# %%
#Should we change the scale to a numerical scale?
#Hard question. It depends. We will return to this later in the course.
#For the moment let's see how to change one, and in the next cell all.
dataSF.replace({'Prob_Return': {'Highly Likely': 7}}, inplace = True) #Replace highly likely with a number
dataSF = dataSF.astype({'Prob_Return': "float"}) #change all the column to numbers
print(dataSF.loc[:, "Prob_Return"].unique())
print(dataSF.dtypes)
# Out:
# [4. 5. 3. 7. 6. 2.]
# ID                         float64
# Regular_Dine_Res           float64
# Dine_Other_Mex_Res         float64
# Income_15k_more            float64
# Fav_Mex_Res                 object
# Try_New_Things              object
# Party_Person                object
# People_Come_Me              object
# No_Fried                   float64
# Likes_Go_Out                object
# Friends_Come_Me             object
# Self_Confident              object
# Eat_Balanced                object
# Buy_New_Prods               object
# Care_What_Eat               object
# Try_New_Brands              object
# Friendly_Employess          object
# Fun_Place                   object
# Large_Portions             float64
# Fresh_Food                  object
# Good_Prices                float64
# Nice_Interior               object
# Excellent_Taste             object
# Knowledgeable_Employees     object
# Proper_Food_Temp            object
# Speed_Service               object
# Satisfaction                object
# Prob_Return                float64
# Prob_Recommend              object
# Freq_Eat_At                 object
# Price                       object
# Food_Quality                object
# Atmosphere                  object
# Service                     object
# Distance_Driven             object
# Ad_Recall                   object
# Gender                      object
# N_Children                  object
# Age                         object
# Income                     float64
# Innovator                   object
# Health_Conscious           float64
# Opinion_Leader              object
# Outgoing                    object
# Service_v2                  object
# Food                        object
# Value                      float64
# Atmosphere_V2               object
# dtype: object

# %%
for c in dataSF.columns:
    u = dataSF.loc[:, c].unique()
    if len(u)>2 and len(u)<20:
        print(c, dataSF.loc[:, c].unique())
# Out:
# Try_New_Things ['Strongly Agree' '3.0' '4.0' '2.0']
# Party_Person ['4.0' '5.0' '2.0' 'Strongly Agree' '6.0' '3.0']
# People_Come_Me ['5.0' '6.0' '4.0' 'Strongly Agree' '3.0' '2.0']
# No_Fried [4. 3. 5. 2. 6.]
# Likes_Go_Out ['4.0' '6.0' '2.0' '5.0' 'Strongly Agree' '3.0']
# Friends_Come_Me ['5.0' '4.0' '6.0' 'Strongly Agree' '3.0']
# Self_Confident ['5.0' '4.0' '6.0' '2.0' 'Strongly Agree' '3.0']
# Eat_Balanced ['4.0' '3.0' '5.0' '2.0' '6.0' 'Strongly Agree']
# Buy_New_Prods ['Strongly Agree' '6.0' '4.0' 'Strongly Disagree' '3.0' '2.0']
# Care_What_Eat ['5.0' '3.0' '6.0' '4.0' '2.0' 'Strongly Agree']
# Try_New_Brands ['4.0' 'Strongly Agree' '3.0']
# Friendly_Employess ['5.0' '3.0' '4.0' '2.0' 'Strongly Disagree']
# Fun_Place ['6.0' '5.0' '4.0' '3.0' '2.0' 'Strongly Agree']
# Large_Portions [4. 6. 5. 3. 2.]
# Fresh_Food ['Strongly Agree' '6.0' '5.0' '4.0']
# Good_Prices [4. 6. 5. 3. 2.]
# Nice_Interior ['6.0' '5.0' '4.0' '3.0' '2.0' 'Strongly Agree']
# Excellent_Taste ['6.0' 'Strongly Agree' '5.0' '4.0' '3.0']
# Knowledgeable_Employees ['4.0' '3.0' '6.0' 'Strongly Agree' 'Strongly Disagree' '2.0']
# Proper_Food_Temp ['4.0' 'Strongly Agree' '6.0' '3.0' '5.0' '2.0']
# Speed_Service ['4.0' 'Strongly Agree' '3.0' 'Strongly Disagree' '2.0' '6.0']
# Satisfaction ['4.0' '6.0' '7 = Highly Satisfied' '5.0' '3.0']
# Prob_Return [4. 5. 3. 7. 6. 2.]
# Prob_Recommend ['3.0' '5.0' '2.0' '6.0' '4.0' 'Definitely Will Recommend']
# Freq_Eat_At ['Occasionally' 'Somewhat Frequently' 'Somewhat Infrequently'
#  'Very Frequently' 'Very Infrequently']
# Price ['Most Important' '2.0' '3.0' 'Least Important']
# Food_Quality ['2.0' '3.0' 'Most Important' 'Least Important']
# Atmosphere ['Least Important' '3.0' 'Most Important' '2.0']
# Service ['3.0' '2.0' 'Least Important' 'Most Important']
# Distance_Driven ['More than 5 miles' '1 -- 5 miles' 'Less than 1 mile']
# N_Children ['No Children at Home' '1-2 Children at Home'
#  'More Than 2 Children at Home']
# Age ['26 - 34' '35 - 49' '50 - 59' '18 - 25' '60 and Over']
# Innovator ['6.0' '4.333333333333333' '4.0' '6.666666666666667' '5.666666666666667'
#  'Strongly Agree' '5.0' '4.666666666666667' '2.0' '3.6666666666666665'
#  '3.3333333333333335' '3.0' '2.6666666666666665']
# Health_Conscious [4.33333333 3.         3.33333333 5.33333333 4.         3.66666667
#  2.33333333 4.66666667 2.66666667 2.         5.66666667 5.
#  6.33333333 6.         6.66666667]
# Opinion_Leader ['5.0' '4.333333333333333' '6.0' '3.3333333333333335' '5.666666666666667'
#  '5.333333333333333' 'Strongly Agree' '4.666666666666667' '4.0'
#  '6.666666666666667' '3.6666666666666665' '6.333333333333333' '3.0'
#  '2.6666666666666665']
# Outgoing ['4.0' '5.5' '2.0' '5.0' 'Strongly Agree' '4.5' '3.5' '6.0' '3.0' '2.5'
#  '6.5']
# Service_v2 ['4.333333333333333' '3.6666666666666665' '5.333333333333333' '5.0' '6.0'
#  '6.333333333333333' '4.0' '2.6666666666666665' '1.6666666666666667'
#  '4.666666666666667' '2.3333333333333335' '5.666666666666667'
#  '3.3333333333333335' '3.0' '2.0' 'Strongly Disagree' '1.3333333333333333']
# Food ['5.666666666666667' '6.666666666666667' '5.333333333333333'
#  '6.333333333333333' '4.333333333333333' '6.0' 'Strongly Agree'
#  '4.666666666666667' '5.0' '4.0' '3.6666666666666665' '3.0']
# Value [4.  6.  4.5 5.  3.  2.  5.5]
# Atmosphere_V2 ['6.0' '5.0' '4.0' '3.0' '4.5' '2.0' '3.5' '5.5' 'Strongly Agree' '6.5']

# %%
#Now all the ordinal ones to numeric
#The Sante Fe grill survey mostly has ordinal variables
s_7 = ["Strongly Agree", "Definitely Will Recommend", '7 = Highly Satisfied'] #score_#
s_6 = []
s_5 = ["Very Frequently", '60 and Over']
s_4 = ["Somewhat Frequently", "Most Important", '50 - 59']
s_3 = ["Occasionally", 'More than 5 miles', 'More Than 2 Children at Home', '35 - 49']
s_2 = ["Somewhat Infrequently", '1 -- 5 miles', '1-2 Children at Home',
      '26 - 34']
s_1 = ["Strongly Disagree", "Very Infrequently", "Least Important", 'Less than 1 mile',
      'No Children at Home', '18 - 25'] 
scores = [s_1, s_2, s_3, s_4, s_5, s_6, s_7]
for c in dataSF.columns:
    u = dataSF.loc[:, c].unique()
    if len(u)>2 and len(u)<20:
        for idx, ele in enumerate(dataSF.loc[:, c]):
            for i, s in enumerate(scores):
                if ele in s:
                    dataSF.loc[idx, c] = i+1
            
        dataSF = dataSF.astype({c: "float"}) #change all the column to numbers
print(dataSF.dtypes)
# Out:
# ID                         float64
# Regular_Dine_Res           float64
# Dine_Other_Mex_Res         float64
# Income_15k_more            float64
# Fav_Mex_Res                 object
# Try_New_Things             float64
# Party_Person               float64
# People_Come_Me             float64
# No_Fried                   float64
# Likes_Go_Out               float64
# Friends_Come_Me            float64
# Self_Confident             float64
# Eat_Balanced               float64
# Buy_New_Prods              float64
# Care_What_Eat              float64
# Try_New_Brands             float64
# Friendly_Employess         float64
# Fun_Place                  float64
# Large_Portions             float64
# Fresh_Food                 float64
# Good_Prices                float64
# Nice_Interior              float64
# Excellent_Taste            float64
# Knowledgeable_Employees    float64
# Proper_Food_Temp           float64
# Speed_Service              float64
# Satisfaction               float64
# Prob_Return                float64
# Prob_Recommend             float64
# Freq_Eat_At                float64
# Price                      float64
# Food_Quality               float64
# Atmosphere                 float64
# Service                    float64
# Distance_Driven            float64
# Ad_Recall                   object
# Gender                      object
# N_Children                 float64
# Age                        float64
# Income                     float64
# Innovator                  float64
# Health_Conscious           float64
# Opinion_Leader             float64
# Outgoing                   float64
# Service_v2                 float64
# Food                       float64
# Value                      float64
# Atmosphere_V2              float64
# dtype: object

# %% [markdown]
# ## Variation

# %%
# Mean and standard deviation
print("MEAN\n", dataSF.mean(numeric_only=True))
print("\nSTD\n", dataSF.std(numeric_only=True))
sns.displot(dataSF.loc[:, "Income"])
# Out:
# MEAN
#  ID                           203.000000
# Regular_Dine_Res               1.000000
# Dine_Other_Mex_Res             1.000000
# Income_15k_more                1.000000
# Try_New_Things                 5.390123
# Party_Person                   4.271605
# People_Come_Me                 5.281481
# No_Fried                       4.113580
# Likes_Go_Out                   4.412346
# Friends_Come_Me                5.308642
# Self_Confident                 4.654321
# Eat_Balanced                   4.567901
# Buy_New_Prods                  5.597531
# Care_What_Eat                  4.427160
# Try_New_Brands                 5.419753
# Friendly_Employess             3.639506
# Fun_Place                      4.637037
# Large_Portions                 4.508642
# Fresh_Food                     5.762963
# Good_Prices                    4.338272
# Nice_Interior                  4.696296
# Excellent_Taste                5.311111
# Knowledgeable_Employees        3.553086
# Proper_Food_Temp               4.523457
# Speed_Service                  5.209877
# Satisfaction                   4.829630
# Prob_Return                    4.464198
# Prob_Recommend                 3.785185
# Freq_Eat_At                    3.244444
# Price                          2.644444
# Food_Quality                   3.224691
# Atmosphere                     2.096296
# Service                        2.034568
# Distance_Driven                2.108642
# N_Children                     1.797531
# Age                            3.039506
# Income                     71683.950617
# Innovator                      5.469136
# Health_Conscious               4.369547
# Opinion_Leader                 5.081481
# Outgoing                       4.341975
# Service_v2                     4.134156
# Food                           5.199177
# Value                          4.423457
# Atmosphere_V2                  4.666667
# dtype: float64
#
# STD
#  ID                           117.057678
# Regular_Dine_Res               0.000000
# Dine_Other_Mex_Res             0.000000
# Income_15k_more                0.000000
# Try_New_Things                 1.863113
# Party_Person                   1.005090
# People_Come_Me                 1.222632
# No_Fried                       1.307608
# Likes_Go_Out                   1.114862
# Friends_Come_Me                1.162981
# Self_Confident                 1.218265
# Eat_Balanced                   1.228158
# Buy_New_Prods                  1.605527
# Care_What_Eat                  1.104784
# Try_New_Brands                 1.766466
# Friendly_Employess             1.209869
# Fun_Place                      0.908764
# Large_Portions                 1.323081
# Fresh_Food                     1.195334
# Good_Prices                    1.237469
# Nice_Interior                  1.019178
# Excellent_Taste                1.084088
# Knowledgeable_Employees        1.517316
# Proper_Food_Temp               1.167874
# Speed_Service                  2.038710
# Satisfaction                   1.118305
# Prob_Return                    1.104369
# Prob_Recommend                 1.198505
# Freq_Eat_At                    1.324559
# Price                          1.148395
# Food_Quality                   0.910001
# Atmosphere                     1.023540
# Service                        0.948574
# Distance_Driven                0.819351
# N_Children                     0.834583
# Age                            0.953586
# Income                     87779.222739
# Innovator                      1.590658
# Health_Conscious               1.099957
# Opinion_Leader                 0.998459
# Outgoing                       0.977958
# Service_v2                     1.384278
# Food                           0.994677
# Value                          1.267088
# Atmosphere_V2                  0.881605
# dtype: float64

# %% [markdown]
# Are there unusual values in income? Let's drop everything within 3 std. dev.

# %%
#Outliers
m = dataSF.loc[:, "Income"].mean()
s = dataSF.loc[:, "Income"].std()
idx = dataSF.loc[:, "Income"] > m -
sns.displot(dataSF.loc[:, "Income"])

# %% [markdown]
# # Covariation

# %% [markdown]
# # Matplotlib
#
# [Based on lectures.scientific-python.org](https://lectures.scientific-python.org/intro/matplotlib)
# [... and Matplotlib documentations](https://matplotlib.org/)

# %% [markdown]
# ## Basic

# %%
# Out:
# Unnamed: 0                                                    int64
# ID                                                          float64
# Regularly Dine at Casual Dining Restaurants                 float64
# Have Dined at Other Mexican Restaurants In last 6 Months    float64
# Gross Annual Income $15,000 or More                         float64
# Favorite Mexican Restaurant                                  object
# X1 -- Try New and Different Things                           object
# X2 -- Party Person                                           object
# X3 -- People Come to Me                                      object
# X4 -- Avoid Fried Foods                                     float64
# X5 -- Likes to Go Out Socially                               object
# X6 -- Friends Come to Me                                     object
# X7 -- Self-Confident                                         object
# X8 -- Eat Balanced, Nutritious Meals                         object
# X9 -- Buy New Products                                       object
# X10 -- Careful about What I Eat                              object
# X11 -- Try New Brands                                        object
# X12 -- Friendly Employees                                    object
# X13 -- Fun Place to Eat                                      object
# X14 -- Large Size Portions                                  float64
# X15 -- Fresh Food                                            object
# X16 -- Reasonable Prices                                    float64
# X17 -- Attractive Interior                                   object
# X18 -- Excellent Food Taste                                  object
# X19 -- Knowledgeable Employees                               object
# X20 -- Proper Food Temperature                               object
# X21 -- Speed of Service                                      object
# X22 -- Satisfaction                                          object
# X23 -- Likely to Return                                      object
# X24 -- Likely to Recommend                                   object
# X25 -- Frequency of Eating at  . . .  ??                     object
# X26 -- Price                                                 object
# X27 -- Food Quality                                          object
# X28 -- Atmosphere                                            object
# X29 -- Service                                               object
# x30 -- Distance Driven                                       object
# X31 -- Ad Recall                                             object
# X32 -- Gender                                                object
# X33 -- Number of Children at Home                            object
# X34 -- Age                                                   object
# X35 -- Income                                               float64
# X36 -- Innovator                                             object
# X37 -- Health Conscious                                     float64
# X38 -- Opinion Leader                                        object
# X39 -- Outgoing                                              object
# X40 -- Service                                               object
# X41 -- Food                                                  object
# X42 -- Value                                                float64
# X43 -- Atmosphere                                            object
# dtype: object

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label = 'Cosine($\\theta$)') #We can use latex expressions surrounded by money signs ($) 
plt.plot(X, S, label = 'Sine($\\theta$)')
plt.legend(loc='upper left')
plt.title("My basic plot")
plt.xlabel("Radians $\\theta$") 
plt.ylabel("Value trig. function");

plt.show()

# %%
#Costumize
# Create a figure of size 8x6 inches, 80 dots per inch
plt.figure(figsize=(8, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)

X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)

# Plot cosine with a blue dashed line of width 4 (pixels)
plt.plot(X, C, color="blue", linewidth=4.0, linestyle="--")

# Plot sine with a green continuous line of width 1 (pixels)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
plt.xlim(-4.0, 4.0)

# Set x ticks
plt.xticks(np.linspace(-4, 4, 9))

# Set y limits
plt.ylim(-1, 1.05)

# Set y ticks
plt.yticks([-1, 0, +1], [r'$-1$', r'$0$', r'$+1$']) #You can change the position and labels of the ticks


#Change splines
# By default, spines are the lines surrounding the figure. 
# We can move them. Comment this and the lines below in or out to check the behavior.
ax = plt.gca()  # gca stands for 'get current axis' i.e. the figure currently active
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

#Annotate
t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))


# Save figure using 72 dots per inch
# plt.savefig("exercise_2.png", dpi=72)

# Show result on screen
plt.show()

# %% [markdown]
# ## Subplots

# %%
fig = plt.figure()
fig.suptitle("Controlling subplot sizes with width_ratios and height_ratios") #sizes can be controlled manually, check https://matplotlib.org/stable/gallery/userdemo/demo_gridspec03.html#gridspec-demo

gs = GridSpec(2, 2, width_ratios=[1, 2], height_ratios=[4, 1]) #creates the specifications of grid to put plots. 
ax1 = fig.add_subplot(gs[0]) #this executes the grid specifications
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])
ax4 = fig.add_subplot(gs[3])

#annotate_axes(fig)
x = np.linspace(0,10)
y = x
ax1.plot(x,y, color = 'green');
x = np.linspace(0,10)
y = x**2
ax4.plot(x,y, color = 'red');
ax4.set_ylim(0,50) #some axis routines have a different syntax (i.e. not .ylim)

# %% [markdown]
# ## Exercise (load + clean + bar plot)
# ### First matplotlib plot
#
# 1) Load movies.csv and name it "movies"
# 2) Print movies head
# 3) Print movies variable types
# 4) Print movies dimensions with the routine .shape
# 4) Clean the variable Weekend gross. Drop from each entry the sign '$' and transform the string values to integer values. Use a for loop and the routine split.
# 5) Print movies variable types again
# 6) With matplotlib, plot an horizontal barplot. Name the axis and write the units.
# 7) Save the figure as png and pdf.

# %% [markdown]
# ## Exercise (load + clean + horizontally stacked bar plot)
# ### A simple plot can be hard in matplotlib
#
# 1) Load income_by_age.csv and name it income_age
# 2) Erase the column "year" from the database
# 3) Print income_age head
# 4) Print income_age variable types
# 5) Print income_age dimensions with the routine .shape
# 6) Go from a long format to a wide format. Use the routine .pivot. Place the resulting table in a new variable called age_race. Print it.
# 7) Reset the index with the routine .reset_index(inplace=True). Print age_race again
# 8) With matplotlib, plot horizontal stacked bars. That is, do in the same figure a barplot of the median income for each age (x-axis) and race.
# One way to do it:
# [matplotlib horizontal stacked bars](https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html)

# %% [markdown]
# # Seaborn = Matplotlib + Pandas + Stats
#
# [Based on seaborn docs](https://seaborn.pydata.org/tutorial)

# %%
#The same horizontally stacked bars are easier in other more expressive packages.
#Seaborn is an excellent alternative
file = "Claus_Wilke_Book_Fund_Data_Viz/data/csv_files/income_by_age.csv"
income_age = pd.read_csv(file)
plt.figure(figsize=(10,5))
sns.barplot(income_age, x="age", y="median_income", hue="race") 
plt.xlabel('Age')
plt.ylabel('Median income')
plt.ylim(0,105000);

# %%
# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = pd.read_csv("tips.csv")
print(tips)

# Create a visualization
sns.relplot( #plot type
    data=tips, #data to use
    x="total_bill", y="tip", col="time", #col is for column; so two columns: Dinner and Lunch
    hue="smoker", style="smoker", size="size", 
);

# %%
#Seaborn can visualize standard stats, like OLS (do not expect the coeficients and stuff; that later)
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker");

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True);

# %%
sns.displot(data=tips, kind="ecdf", x="total_bill", col="time", hue="smoker", rug=True);

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker");

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True);

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker");

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", hue="smoker");

# %%
sns.pairplot(data=tips, hue="smoker");

# %%
g = sns.PairGrid(tips, hue="smoker", corner=True) #put the info in an object
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %% [markdown]
# <img src="plot_types_seaborn.png">

# %% [markdown]
# ## Exercise (load + clean + heatmap)
# Elaborated charts with relatively few lines of code
#
# 1) Load the data set Internet_user.csv and put it in a variable called Internet
# 2) print the name of the columns of Internet
# 3) print the dimensions of Internet with the routine .shape
# 4) Make a new data called Internet_R with only these countries:
#   Iceland, Norway, Japan, France, United States, Mexico, Argentina, Colombia, Kenya, China.
#   Use the routine filter. Important: the parameter items in filter only works on names of rows or columns. Thus, temporarily, make the country code the index, and then use .reset_index(drop=True)
# 5) Print Internet_R head and confirm it has the same number of rows and the countries you asked for.
# 6) Make a new reduced data called Internet_hm, with only the years i.e. drop the remaining columns
# 7) Rename the index of Internet_hm with the country names
# 8) Rename the axis of Internet_hm with the routine .rename_axis(). Call the columns axis year; the index axis country
# 8) Make a heatmap with seaborn with Internet_hm. Save the figure as png and pdf.

# %% [markdown]
# # Grammar of graphics

# %% [markdown]
# ## ggplot
# As implemented in P9

# %%
#A simple example from p9 documentation
df = pd.DataFrame({
    'letter': ['Alpha', 'Beta', 'Delta', 'Gamma'],
    'pos': [1, 2, 3, 4],
    'num_of_letters': [5, 4, 5, 5]
}) #silly dataset

df

# %%
#This is a nice simple example to see the logic of ggplot grammar of graphics
p = (ggplot(df) #indicate the data to use
 + geom_col(aes(x='letter', y='pos')) #geom 1 (first layer)
 + geom_line(aes(x='letter', y='num_of_letters'), group=1) #geom 2 (second layer)
 + p9.labs(title='Greek Letter Analysis', x = 'Letter', y = 'Position') #misc
)
p

# %%
#Forest plot. See an example in google images
#Plan: we want to tell ggplot to paint dots and confidence intervals
#That is, at least two layers.

#Load data set
file = "Claus_Wilke_Book_Fund_Data_Viz/data/csv_files/cacao.csv"
chocolate = pd.read_csv(file)
countries = np.array(['Switzerland', 'Canada', 'Austria', 'U.S.A.', 'Belgium', 'Peru'])
boolean = ""
for c in countries:
    boolean = boolean + c + "|"
chocolate_R = chocolate[chocolate["location"].str.contains(boolean[0:-1])].reset_index(drop=True)
chocolate_R

# %%
Cho_Stats = chocolate_R.groupby(['location']).agg({'rating': ['mean', 'std']}).reset_index(drop=True)
Cho_Stats.insert(0, 'location', list(chocolate_R.groupby(['location']).indices.keys()))
Cho_Stats.columns = ['location', 'mean_rating', 'std_rating']
Cho_Stats.insert(Cho_Stats.shape[1], 'error_left', Cho_Stats.loc[:,'mean_rating'] - Cho_Stats.loc[:,'std_rating'])
Cho_Stats.insert(Cho_Stats.shape[1], 'error_right', Cho_Stats.loc[:,'mean_rating'] + Cho_Stats.loc[:,'std_rating'])
Cho_Stats.columns = ['location', 'mean_rating', 'std_rating', 'error_left', 'error_right']
p = ggplot(Cho_Stats, aes(y = "location")) + p9.theme_classic()
#p

# %%
p = (p +  
     geom_point(aes(x="mean_rating"), shape="o", size=3) + 
     geom_errorbarh(aes(xmin="error_left", xmax="error_right", y = 'location')) +
     p9.labs(title = "Chocolate Ratings", x = 'Rating', y = 'Country')
    ) 
p

# %%
#Age pyramid (see Figure 7.10 https://clauswilke.com/dataviz/histograms-density-plots.html)
#This one is more complicated. 
#But think it again in terms of layers.
#We need to layers/geoms: one for the female histogram, another for the male histogram

#First let's build the histograms. 
#One problem is that the native geom_histogram only gives us positive counts
#Another problem is that flipping only one scale of a geom (0 to 50 towards negative) is hard 
#So we need to build our histograms to feed as data to geom_bar (not use geom_histogram)
file = "Claus_Wilke_Book_Fund_Data_Viz/data/csv_files/titanic_all.csv"
titanic = pd.read_csv(file)
titanic.dropna(inplace = True)
titanic_male = titanic.loc[titanic['sex'] == 'male', 'age'].reset_index(drop = True)
titanic_female = titanic.loc[titanic['sex'] == 'female', 'age'].reset_index(drop = True)

h = np.histogram(titanic_male, bins=10)
bin_edges = h[1]
bin_width = np.diff(h[1])[0]
h = np.array([(h[1] + bin_width/2)[0:-1], h[0]]).transpose()
df_m = pd.DataFrame(h, columns = ['Age_center', 'Counts'])

h = np.histogram(titanic_female, bins = bin_edges)
h = np.array([(h[1] + np.diff(h[1])[0]/2)[0:-1], -h[0]]).transpose()
df_f = pd.DataFrame(h, columns = ['Age_center', 'Counts'])

# %%
breaks = np.sort(np.append(np.linspace(-130, 130, df_m.shape[0]), 0))
labels = list(np.array(np.array(np.abs(breaks),dtype=int), dtype = str))
(ggplot() +
 geom_bar(df_f, aes(x='Age_center', y = 'Counts'), stat = "identity", fill = 'blue', width = 0.98*bin_width) +
 geom_bar(df_m, aes(x='Age_center', y = 'Counts'), stat = "identity", fill = 'red', width = 0.98*bin_width) +
 coord_flip() + p9.scale_y_continuous(breaks = breaks, labels = labels, limits = [-130,130]) +
 p9.labs(x = 'Age (Years)') + p9.theme_classic()
)

# %% [markdown]
# ## Exercise (Densities + Faceting)
# Learn to plot on the same chart or on different panels.
#
# 1) Load titanic_all.csv data
# 2) Drop unnecesary columns "name", "class", "survived"
# 3) Remove NaN
# 4) Plot, with plotnine, age densities with geom_density: for male, for female. Use facet_grid. Change the defaul theme to one of your preference
# 5) Do not use facet_grid. Both distributions in the same chart. Fill each sex distribution with color and make it slightly transparent. Change the plot labels and put a title of your liking. Do the same for the legend.

# %% [markdown]
# ## HoloViews
# Based on [HoloViews documentation](https://holoviews.org/getting_started/)
#
# Gallery on [Gallery](https://holoviews.org/reference/index.html)
#
# HoloViews can render using different libraries. Here we will use bokeh.

# %%
station_info = pd.read_csv('station_info.csv')
station_info.head()

# %%
#A visualization with HoloViews. 
scatter = hv.Scatter(station_info, 'services', 'ridership')
scatter

# %%
#The object scatter is a wrapper of info useful to HoloViews, not a plot object. 
#Scatter is plotting-package agnostic, it works with matplotlib, plotly, or bokeh as possible backends
#HoloViews objects contain:
#   Your data
#   Metadata specifying what your data is
print(scatter)

# %%
#Composing ... the plus is a shortcut for different pannel
layout = scatter + hv.Histogram(np.histogram(station_info['opened'], bins=24), kdims=['opened'])
layout

# %%
#To reiterate, layout is a wrapper, not a plot object
print(layout)

# %%
#Array data (.npz is a numpy array compressed)
taxi_dropoffs = {hour:arr for hour, arr in np.load('hourly_taxi_data.npz').items()} #Dictionary; each key is an hour
print('Hours: {hours}'.format(hours=', '.join(taxi_dropoffs.keys())))
print('Taxi data contains {num} arrays (one per hour).\nDescription of the first array:\n'.format(num=len(taxi_dropoffs)))
print(np.info(taxi_dropoffs['0']))
taxi_dropoffs['0']

# %%
#Composing ... the times sign crosses both images on the same chart
bounds = (-74.05, 40.70, -73.90, 40.80)
image = hv.Image(taxi_dropoffs['0'], ['lon','lat'], bounds=bounds)
points = hv.Points(station_info, ['lon','lat']).opts(color="red")
image + image * points

# %%
#A holomap it is useful to explora data. It has some interactivity features.
#This holomap is a dictionary with many images
dictionary = {int(hour):hv.Image(arr, ['lon','lat'], bounds=bounds) 
              for hour, arr in taxi_dropoffs.items()} 
holomap = hv.HoloMap(dictionary, kdims='Hour') #key, in the key:value pair, is interpreted as kdim...write the name you prefer
print(holomap)
holomap

# %%
#A static version
holomap.select(Hour={3,6,9}).layout()

# %%
#More compositions ... 
#... and see how with .opts we can costumize our plot (check more in https://holoviews.org/getting_started/Customization.html)
hotspot = points.select(lon=(-73.99, -73.96), lat=(40.75,40.765)) #South of Central Park contains many popular tourist attractions, including Times Square
composition = holomap * hotspot

composition.opts(
    opts.Image(xrotation=90), #the rotation is on the labels
    opts.Points(color='red', marker='v', size=6))

# %%
#A static version
composition.select(Hour=7)

# %%
#Holoviews objects have the relevant slices of data (and other info used by HoloViews)
#That's why the objects can be plotted with different engines 
#see https://holoviews.org/gallery/ for available plots of different engines
hotspot.data

# %%
#You can save to many formats, including html for the interactive stuff
hv.save(composition, 'holomap.html') #the whole interaction, it is a stand alone file, you can send it to anyone and they will see it fine
hv.save(composition.last, 'image.html') #a frame

# %%
#BONUS: Network plot
kwargs = dict(width=800, height=800, xaxis=None, yaxis=None)
opts.defaults(opts.Nodes(**kwargs), opts.Graph(**kwargs))

colors = ['#000000']+hv.Cycle('Category20').values
edges_df = pd.read_csv('fb_edges.csv')
fb_nodes = hv.Nodes(pd.read_csv('fb_nodes.csv')).sort()
fb_graph = hv.Graph((edges_df, fb_nodes), label='Facebook Circles')

fb_graph.opts(cmap=colors, node_size=10, edge_line_width=1,
              node_line_color='gray', node_color='circle')

# %%
#This makes it prettier
bundled = bundle_graph(fb_graph)
bundled

# %% [markdown]
# ## Tabular data

# %%
#Tabular (old plain data we've been using) and gridded data (e.g. 4D objects like fMRI slices, x,y,z,time)
#Let's start with tabular
diseases = pd.read_csv('diseases.csv.gz')
diseases.head()

# %%
#In holoviews, kdim are akin to independent variables (key dimensions)
#Dependent variables are vdim (value dimensions).
#We can create a holoviews data set and put better descriptions to a dimension.

vdims = [('measles', 'Measles Incidence'), ('pertussis', 'Pertussis Incidence')]
ds = hv.Dataset(diseases, ['Year', 'State'], vdims) #Year and State are key (the first gets plotted, then they get a dropdown menu), measles and pertussis are value dimensions
ds = ds.aggregate(function=np.mean) #We average over the remaining dimensions i.e. week dimension
ds

# %%
#Now let's plot
#ds.to(plot-type, kdim, vdim) i.e. in natural language ...
#map kdim, vdim to plot-type
#Because state is not in, the dropdown menu is State
layout = (ds.to(hv.Curve, 'Year', 'measles') + ds.to(hv.Curve, 'Year', 'pertussis')).cols(1)
layout.opts(
    opts.Curve(width=600, height=250, framewise=True))

# %%
#As usual in python, we can compose functions
#More interesting, is that .Bars receives the two key dimensions, State, Year (or flip it)
#and cross them appropietely (under the limits of a barplot)
states = ['New York', 'New Jersey', 'California', 'Texas'] #
bars = ds.select(State=states, Year=(1980, 1990)).to(hv.Bars, ['State', 'Year'], 'measles').sort()
bars.opts(
    opts.Bars(width=800, height=400, tools=['hover'], xrotation=90, show_legend=False))

# %%
#Faceting is straight forward
grouped = ds.select(State=states, Year=(1930, 2005)).to(hv.Curve, 'Year', 'measles')
gridspace = grouped.grid('State')
gridspace.opts(
    opts.Curve(width=200, color='indianred'))

# %%
#Or everything in one plot
ndoverlay = grouped.overlay('State')
ndoverlay.opts(
    opts.Curve(width=600, color=hv.Cycle(values=['indianred', 'slateblue', 'lightseagreen', 'coral'])))

# %%
#Aggregation e.g. useful for error bars
agg = ds.aggregate('Year', function=np.mean, spreadfn=np.std)
errorbars = hv.ErrorBars(agg,vdims=['measles', 'measles_std']).iloc[::2]
overlay =  (hv.Curve(agg) * errorbars).redim.range(measles=(0, None))

overlay.opts(width=600)

# %% [markdown]
# ## Grided Data
# Data across dimensions. Better with and example: an RGB image sequence over time; maps of sales in a region over time; the trafic data on previous examples

# %%
#The data are 2D images across time 
data = np.load('twophoton.npz')
calcium_array = data['Calcium']
calcium_array.shape

# %%
ds = hv.Dataset((np.arange(50), np.arange(111), np.arange(62), calcium_array),
                ['Time', 'x', 'y'], 'Fluorescence')
ds

# %%
#Some defaults for what comes
opts.defaults(
    opts.GridSpace(shared_xaxis=True, shared_yaxis=True),
    opts.Image(cmap='viridis', width=400, height=400),
    opts.Labels(text_color='white', text_font_size='8pt', text_align='left', text_baseline='bottom'),
    opts.Path(color='white'),
    opts.Spread(width=600),
    opts.Overlay(show_legend=False))

# %%
ds.to(hv.Image, ['x', 'y']).hist() #The dropdown menu is with time, because we didn't use it in the function call

# %%
ROIs = data['ROIs'] #Region of interest
roi_bounds = hv.Path([hv.Bounds(tuple(roi)) for roi in ROIs])
print(ROIs.shape)
labels = hv.Labels([(roi[0], #"x"
                     roi[1], #"y"
                     i) for i, roi in enumerate(ROIs)])
(ds[21].to(hv.Image, ['x', 'y']) * roi_bounds * labels).relabel('Time: 21')

# %%
#A specific region
x0, y0, x1, y1 = ROIs[60]
roi = ds.select(x=(x0, x1), y=(y0, y1), time=(250, 280)).relabel('ROI #60')
roi.to(hv.Image, ['x', 'y'])

# %%
#Another representation
roi.to(hv.Curve, 'Time').grid()

# %%
#Aggregate over space
agg = roi.aggregate('Time', np.mean, spreadfn=np.std)
hv.Spread(agg) * hv.Curve(agg)

# %% [markdown]
# ## Exercise (Geodata)
# Make sure USA_coords was loaded (it should be in the package import section)
# If not, load it with this:
# import pickle
# with open('USA_coords.pickle', 'rb') as handle:
#     b = pickle.load(handle)
#
# Data setup to plot the US map. The info of each state should be in a dictionary. And each dictionary should be an element of a list. We drop Alaska and Hawaii
#
# us_states = [dict(state[1]) for state in USA_coords.items() if (state[0]!="AK") & ((state[0]!="HI")) ]
#
# Now the exercise with HoloViews
#
# 1) Load wind_turbines.csv and name it wind_turbines
# 2) Print wind_turbines head
# 3) Print wind_turbines columns
# 4) Drop Alaska (AK), Guam (GU), Hawaii (HI), Puerto Rico (PR) from wind_turbines. Name the reduced data wind_turbines_R
# 5) Plot the USA map with hv.Polygons. Tip: us_states have the longitudes and latitudes. Make sure the background is white and the frontiers between states black. Name the plot us_map
# 6) Plot the turbines on wind_turbines_R with hv.Points. Make them red and with the marker 'v'. Name the plot turb_plot
# 7) Plot us_map and turb_plot on the same chart

# %% [markdown]
# # Interactivity

# %%
#Other example
def clifford_equation(a,b,c,d,x0,y0):
    xn,yn = x0,y0
    coords = [(x0,y0)]
    for i in range(10000):
        x_n1 = np.sin(a*yn) + c*np.cos(a*xn)
        y_n1 = np.sin(b*xn) + d*np.cos(b*yn)
        xn,yn = x_n1,y_n1
        coords.append((xn,yn))
    return coords

def clifford_attractor(a,b,c,d):
    return hv.Points(clifford_equation(a,b,c,d,x0=0,y0=0))

# %%
opts.defaults(
    opts.Curve(color='black'),
    opts.Points(color='red', alpha=0.1, width=400, height=400))

# %%
clifford = hv.DynamicMap(clifford_attractor, kdims=['a','b','c','d'])
clifford.redim.range(a=(-1.5,-1),b=(1.5,2),c=(1,1.2),d=(0.75,0.8), x=(-2,2), y=(-2,2))

# %% [markdown]
# ## Exercise (Interactive)
#
# 1) Load vgsales.csv and name it vg_sales
# 2) Sort vg_sales by Year (inplace = True)
#     1) Do vg_sales.reset_index(drop = True, inplace = True) of vg_sales
# 4) Replicate the measles example to do an interactive plot with holoviews, using hv.Curve. Make Global_Sales the vdim. Year and Genre kdims. Use np.mean as an aggregate function over the remaining variables/columns. Modify the y axis limits.
# 5) Now do the same but with an additional kdim: Platform. You should get now two dropdown menus, one for Genre, another for Platform.
#
# Bonus: try to do an interactive plot with hv.DynamicMap. You will have to define a function. The arguments would be info to slice up vg_sales.

# %% [markdown]
# # Appendix

# %% [markdown]
# Do an alluvial_diagram with one package!! e.g. https://github.com/vinsburg/alluvial_diagram
